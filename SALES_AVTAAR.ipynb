# %% [markdown]
# <a href="https://colab.research.google.com/github/RohanRaj12/Avtaar/blob/main/SALES_AVTAAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a4638e96-c436-47f5-8c23-a63510678969" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a4638e96-c436-47f5-8c23-a63510678969">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sales_full_data.csv to sales_full_data (1).csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales_full_data.csv")

# %%
df
# Out:
#        Order ID  ...                         Purchase Address
# 0        176558  ...             917 1st St, Dallas, TX 75001
# 1           NaN  ...                                      NaN
# 2        176559  ...        682 Chestnut St, Boston, MA 02215
# 3        176560  ...     669 Spruce St, Los Angeles, CA 90001
# 4        176560  ...     669 Spruce St, Los Angeles, CA 90001
# ...         ...  ...                                      ...
# 186845   259353  ...   840 Highland St, Los Angeles, CA 90001
# 186846   259354  ...  216 Dogwood St, San Francisco, CA 94016
# 186847   259355  ...     220 12th St, San Francisco, CA 94016
# 186848   259356  ...   511 Forest St, San Francisco, CA 94016
# 186849   259357  ...   250 Meadow St, San Francisco, CA 94016
#
# [186850 rows x 6 columns]

# %%
df.isnull()
# Out:
#         Order ID  Product  ...  Order Date  Purchase Address
# 0          False    False  ...       False             False
# 1           True     True  ...        True              True
# 2          False    False  ...       False             False
# 3          False    False  ...       False             False
# 4          False    False  ...       False             False
# ...          ...      ...  ...         ...               ...
# 186845     False    False  ...       False             False
# 186846     False    False  ...       False             False
# 186847     False    False  ...       False             False
# 186848     False    False  ...       False             False
# 186849     False    False  ...       False             False
#
# [186850 rows x 6 columns]

# %%
df = df.dropna()
df
# Out:
#        Order ID  ...                         Purchase Address
# 0        176558  ...             917 1st St, Dallas, TX 75001
# 2        176559  ...        682 Chestnut St, Boston, MA 02215
# 3        176560  ...     669 Spruce St, Los Angeles, CA 90001
# 4        176560  ...     669 Spruce St, Los Angeles, CA 90001
# 5        176561  ...        333 8th St, Los Angeles, CA 90001
# ...         ...  ...                                      ...
# 186845   259353  ...   840 Highland St, Los Angeles, CA 90001
# 186846   259354  ...  216 Dogwood St, San Francisco, CA 94016
# 186847   259355  ...     220 12th St, San Francisco, CA 94016
# 186848   259356  ...   511 Forest St, San Francisco, CA 94016
# 186849   259357  ...   250 Meadow St, San Francisco, CA 94016
#
# [186305 rows x 6 columns]

# %%
df.isnull()
# Out:
#         Order ID  Product  ...  Order Date  Purchase Address
# 0          False    False  ...       False             False
# 2          False    False  ...       False             False
# 3          False    False  ...       False             False
# 4          False    False  ...       False             False
# 5          False    False  ...       False             False
# ...          ...      ...  ...         ...               ...
# 186845     False    False  ...       False             False
# 186846     False    False  ...       False             False
# 186847     False    False  ...       False             False
# 186848     False    False  ...       False             False
# 186849     False    False  ...       False             False
#
# [186305 rows x 6 columns]

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
list(df.columns)
# Out:
# ['Order ID',
#  'Product',
#  'Quantity Ordered',
#  'Price Each',
#  'Order Date',
#  'Purchase Address']

# %%
df = df[df['Quantity Ordered'] != 'Quantity Ordered']

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Price Each'] = pd.to_numeric(df['Price Each'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Sales'] = df['Quantity Ordered'] * df['Price Each']
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Order ID  ...   Sales
# 0        176558  ...   23.90
# 2        176559  ...   99.99
# 3        176560  ...  600.00
# 4        176560  ...   11.99
# 5        176561  ...   11.99
# ...         ...  ...     ...
# 186845   259353  ...    8.97
# 186846   259354  ...  700.00
# 186847   259355  ...  700.00
# 186848   259356  ...  379.99
# 186849   259357  ...   11.95
#
# [185950 rows x 7 columns]

# %%
df['Month'] = df['Order Date'].str[0:2]
df['Month'] = df['Month'].astype('int32')
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Order ID                     Product  ...   Sales  Month
# 0   176558        USB-C Charging Cable  ...   23.90      4
# 2   176559  Bose SoundSport Headphones  ...   99.99      4
# ...

# %%
mon = df.groupby('Month').sum()
mon
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %% [markdown]
# # **1. The HIGHEST SALES was in DECEMBER and LOWEST SALES was in JANUARY, Since this is the end of the year and festive season therefore the customers had done the shopping in Dec.**

# %%
months = range(1,13)
plt.bar(months,mon['Sales'])
plt.xticks(months)
plt.ylabel('Sale in USD $')
plt.xlabel('Months')
# Out:
# Text(0.5, 0, 'Months')

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df["Hour"] = df['Order Date'].dt.hour
df["Minute"] = df['Order Date'].dt.minute
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
hours = df.groupby('Hour').sum()
hours
# Out:
#       Quantity Ordered  Price Each       Sales  Month  Minute
# Hour
# 0                 4428   709296.70   713721.27  27554  103596
# 1                 2619   458490.00   460866.88  16657   61807
# 2                 1398   233833.64   234851.44   8507   32508
# 3                  928   144726.42   145757.89   5904   23044
# 4                  937   162058.18   162661.01   6148   26876
# 5                 1493   229621.21   230679.82   9301   42877
# 6                 2810   445000.11   448113.00  17539   80343
# 7                 4556   740568.11   744854.12  28850  127447
# 8                 7002  1185970.62  1192348.97  43626  198135
# 9                 9816  1628498.49  1639030.58  60981  268253
# 10               12308  1932665.62  1944286.77  76928  331941
# 11               14005  2288855.18  2300610.24  87654  368952
# 12               14202  2299876.68  2316821.34  89161  368679
# 13               13685  2139743.86  2155389.80  85808  351045
# ...

# %% [markdown]
# # **2. I will put the advertisement from 12 to 16 hours because there is decrease in the sales during that time.**

# %%
hours = [hour for hour, df in df.groupby('Hour')]
plt.plot(hours,df.groupby(['Hour']).count())
plt.xticks(hours)
plt.xlabel('Hours')
plt.ylabel('Number of orders')
# Out:
# Text(0, 0.5, 'Number of orders')

# %% [markdown]
# # 3. The top products that were sold was
#     a.USB-C Charging Cable
#     b.Lightning Charging Cable
#     c.AAA Batteries (4-pack)
#     d.AA Batteries (4-pack)
#     e.Wired Headphones

# %%
data = []

for Product in df['Product'].unique():
    data.append([Product , len(df[df['Product']  == Product])])

pd.DataFrame(data,columns = ['Product','No. of Product']).sort_values(by='No. of Product', ascending=False).plot(x = 'Product', y = 'No. of Product', kind = 'bar', figsize = (10,5),color='red')
